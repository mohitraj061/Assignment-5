# %% [raw]
# Ques 1.) What does an empty dictionary's code look like ?
#
# Solution :
#
# In Python, an empty dictionary is represented by a pair of curly braces {}. Here's an example of the code to create an
# empty dictionary :
#
# empty_dict = {}
#
# After executing this code, the variable empty_dict will be an empty dictionary.

# %% [raw]
# Ques 2.) What is the value of a dictionary value with the key 'foo' and the value 42 ?
#
# Solution :
#
# The value of a dictionary with the key 'foo' and the value 42 would be 42. In Python, dictionaries are a collection of
# key-value pairs, where each key is unique and associated with a corresponding value. we can access the value of a
# dictionary using its key. Here's an example :
#
# my_dict = {'foo': 42}
# value = my_dict['foo']
# print(value)  # Output: 42
#
# In this example, the dictionary my_dict has a key 'foo' with the value 42. The value is accessed using the key 'foo' with
# the square bracket notation (my_dict['foo']) and assigned to the variable value. Finally, the value is printed, which will
# output 42.

# %% [raw]
# Ques 3.) What is the most significant distinction between a dictionary and a list ?
#
# Solution :
#
# The most significant distinction between a dictionary and a list is the way they store and retrieve data.
#
# 1.) Structure :
#
# * List : A list is an ordered collection of items where each item is identified by its position or index. Lists maintain the
#   order of elements as they are inserted.
#
# * Dictionary : A dictionary is an unordered collection of key-value pairs. Each key is unique within the dictionary, and it
#   is used to access its corresponding value. The order of elements in a dictionary is not guaranteed.
#
# 2.) Data Access :
#
# * List : In a list, data is accessed by its index position, starting from 0. For example, my_list[0] retrieves the first item
#   in the list.
#
# * Dictionary : In a dictionary, data is accessed using keys. Each key in the dictionary maps to a corresponding value.
#   For example, my_dict['key'] retrieves the value associated with the key 'key'.
#
# 3.) Mutable vs Immutable :
#
# * List : Lists are mutable, meaning you can change, add, or remove elements after the list is created. You can modify the
#   values at specific indices or use methods like append(), remove(), insert(), etc.
#
# * Dictionary : Dictionaries are also mutable. You can modify, add, or delete key-value pairs in a dictionary. You can change
#   the value associated with a key, add new key-value pairs, or remove existing key-value pairs.
#
# 4.) Usage :
#
# * List : Lists are useful for storing an ordered collection of items, especially when the order of elements is important.
#   Lists are commonly used when you want to work with a sequence of items or iterate over them.
#
# * Dictionary : Dictionaries are ideal when you want to associate values with unique keys and need fast access to those values.
#   They are used to represent mappings or relationships between different entities.
#
# In summary, lists are ordered collections accessed by indices, while dictionaries are unordered collections accessed by keys.
# Lists are suitable when maintaining the order of elements is important, whereas dictionaries are useful for quick access to
# values based on unique keys.

# %% [raw]
# Ques 4.) What happens if you try to access spam['foo'] if spam is {'bar':100} ?
#
# Solution :
#
# If we try to access spam['foo'] and spam is {'bar': 100}, it will raise a KeyError.
#
# In Python, when we try to access a key in a dictionary that doesn't exist, a KeyError is raised. This occurs because the
# key 'foo' does not exist in the dictionary spam with the only key 'bar'.
#
# Here's an example:
#
# spam = {'bar': 100}
# value = spam['foo']
#
# Output :
#     KeyError: 'foo'
#
# The error message indicates that the key 'foo' is not found in the dictionary, resulting in a KeyError being raised.

# %% [raw]
# Ques 5.) If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in
#          spam.keys() ?
#
# Solution :
#
# The expressions 'cat' in spam and 'cat' in spam.keys() check for the presence of the key 'cat' in the dictionary spam,
# but they have a slight difference in their behavior:
#
# 1.) 'cat' in spam :
#
# This expression checks if the key 'cat' exists directly in the dictionary spam. It returns True if the key is present and
# False otherwise. It checks for key existence only.
#
# 2.) 'cat' in spam.keys() :
#
# This expression retrieves all the keys from the dictionary spam using the keys() method and then checks if the key 'cat'
# exists among those keys. It returns True if the key is present and False otherwise. It checks for key existence within the
# list of keys.
#
# The practical difference between these expressions lies in their performance and behavior:
#
# * 'cat' in spam directly checks for key existence in the dictionary without generating a separate list of keys. It is
# generally more efficient because dictionary key lookups are highly optimized for performance. This approach is preferred when
# we only need to check the presence of a specific key.
#
# *'cat' in spam.keys() retrieves all the keys in spam and creates a list of keys before checking for the presence of 'cat'.
# Generating the list of keys may require additional memory and time, especially for large dictionaries. This approach
# is useful if we need to iterate over or perform operations on the keys in addition to checking for the presence of a
# specific key.
#
# In summary, 'cat' in spam directly checks if 'cat' is a key in the dictionary spam, while 'cat' in spam.keys() generates a
# list of keys and then checks if 'cat' is present in that list. The former is more efficient for simple key existence checks,
# while the latter is useful when we also need to work with the list of keys.

# %% [raw]
# Ques 6.) If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in
#          spam.values() ?
#
# Solution :
#
# The expressions 'cat' in spam and 'cat' in spam.values() have different purposes and behaviors when it comes to checking
# the presence of a value in a dictionary spam:
#
# 1.) 'cat' in spam :
#
# This expression checks if the value 'cat' exists in any of the values of the dictionary spam. It returns True if the value
# is found and False otherwise. It iterates over the values of the dictionary to perform the check.
#
# 2.) 'cat' in spam.values() :
#
# This expression retrieves all the values from the dictionary spam using the values() method and then checks if the value
# 'cat' exists among those values. It returns True if the value is present and False otherwise. It checks for value existence
# within the list of values.
#
# The practical difference between these expressions lies in what they are checking :
#
# * 'cat' in spam checks if the value 'cat' exists in any of the values in the dictionary spam.
#
# * 'cat' in spam.values() checks if the value 'cat' exists in the list of values extracted from the dictionary spam.
#
# Here's an example to illustrate the difference :
#
# spam = {'animal1': 'dog', 'animal2': 'cat', 'animal3': 'elephant'}
#
# print('cat' in spam)             # Output: False (since 'cat' is not a key)
# print('cat' in spam.values())    # Output: True  (since 'cat' is a value in the dictionary)
#
# In the given example, 'cat' in spam returns False because 'cat' is not a key in the dictionary spam. On the other hand,
# 'cat' in spam.values() returns True because 'cat' is one of the values in the dictionary.

# %% [raw]
# Ques 7.) What is a shortcut for the following code ?
#
#          if 'color' not in spam :
#          spam['color']='black'
#
# Solution :
#
# A shortcut for the given code can be achieved using the dict.setdefault() method. This method allows us to set a default
# value for a key if the key is not already present in the dictionary. Here's the equivalent shortcut for the code :
#
# spam.setdefault('color', 'black')
#
# This line of code will check if the key 'color' exists in the spam dictionary. If the key is not found, it will set the key
# 'color' to the value 'black'. If the key already exists, it will leave it unchanged.
#
# The setdefault() method returns the value associated with the key 'color', which is either the existing value if the key
# is present or the newly set default value 'black' if the key is not present.
#
# Using setdefault() provides a concise way to achieve the same behavior as the if condition in your original code.

# %% [raw]
# Ques 8.) How do you "pretty print" dictionary values using which module and function ?
#
# Solution :
#
# To "pretty print" dictionary values in Python, we can make use of the pprint module and its pprint() function. The pprint
# module provides a way to format and display complex data structures in a more readable and aesthetically pleasing manner.
#
# Here's an example of how to use pprint to pretty print dictionary values :
#
# import pprint
# my_dict = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}
# pprint.pprint(my_dict)
#
# Output :
# {'key1': 'value1',
# 'key2': 'value2',
# 'key3': 'value3'}
#
# In this example, we import the pprint module and create a dictionary my_dict with some key-value pairs. We then use the
# pprint.pprint() function to pretty print the dictionary. The resulting output displays the dictionary in a well-formatted
# and readable manner, with each key-value pair on a separate line and proper indentation.
#
# The pprint() function can handle dictionaries, lists, tuples, and other complex data structures, making it a convenient
# tool for printing them in a more organized and visually appealing way.
